# %% [markdown]
# # BinX tech AI & ML Internship
#
# ## Week 1 - Day 1
#
# ### Environment Setup
#
# This notebook verfies that the Python environment is configured correctly.
#
# Libraries :
# - NumPy
# - Pandas
# - Matplotlib
# - Jupyter

# %%
import numpy as np
import pandas as pd
import matplotlib

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# NumPy version: 2.5.1
# Pandas version: 3.0.3
# Matplotlib version: 3.11.1
