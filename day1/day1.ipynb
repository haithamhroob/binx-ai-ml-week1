# %% [markdown]
# # BinX tech AI & ML Internship
#
# ## Week 1 - Day 1
#
# ### Environment Setup
#
# this notbook verfies that the python environment is configured correctly.
#
# Libraries :
# - NumPy
# - Pandas
# - Matplotlib
# - Jupyter

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", plt.matplotlib.__version__)
